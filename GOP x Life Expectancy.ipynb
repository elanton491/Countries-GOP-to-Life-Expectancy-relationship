# %%
import numpy as np
np.set_printoptions(suppress=True)

import pandas as pd
idx = pd.IndexSlice
pd.options.display.max_columns = 100

# %matplotlib inline
import matplotlib.pyplot as plt

import seaborn as sb

# %%
csv1_df = pd.read_csv('8aed530e-5a29-4566-880e-e01fb39d9e07_Data.csv', index_col='Country Name')

csv1_df.head()
# Out:
#               Country Code                              Series Name  \
# Country Name
# China                  CHN  Life expectancy at birth, total (years)
# United States          USA  Life expectancy at birth, total (years)
# Thailand               THA  Life expectancy at birth, total (years)
# Madagascar             MDG  Life expectancy at birth, total (years)
# NaN                    NaN                                      NaN
#
#                   Series Code  2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  \
# Country Name
# China          SP.DYN.LE00.IN      71.732000      72.061000      72.381000
# United States  SP.DYN.LE00.IN      76.836585      76.936585      77.036585
# Thailand       SP.DYN.LE00.IN      70.832000      71.089000      71.389000
# Madagascar     SP.DYN.LE00.IN      59.129000      59.717000      60.256000
# NaN                       NaN            NaN            NaN            NaN
#
# ...

# %%
csv1_df.shape
# Out:
# (9, 22)

# %%
csv1_df.dtypes
# Out:
# Country Code      object
# Series Name       object
# Series Code       object
# 2001 [YR2001]    float64
# 2002 [YR2002]    float64
# 2003 [YR2003]    float64
# 2004 [YR2004]    float64
# 2005 [YR2005]    float64
# 2009 [YR2009]    float64
# 2010 [YR2010]    float64
# 2011 [YR2011]    float64
# 2012 [YR2012]    float64
# 2013 [YR2013]    float64
# 2014 [YR2014]    float64
# 2015 [YR2015]    float64
# 2016 [YR2016]    float64
# 2017 [YR2017]    float64
# 2018 [YR2018]    float64
# 2019 [YR2019]    float64
# 2020 [YR2020]    float64
# 2021 [YR2021]     object
# dtype: object

# %%
del csv1_df['Country Code']
del csv1_df['Series Name']
del csv1_df['Series Code']

# %%
del csv1_df['2021 [YR2021]']

# %%
csv1_df.T
# Out:
# Country Name    China  United States  Thailand  Madagascar  NaN  NaN  NaN  \
# 2001 [YR2001]  71.732      76.836585    70.832      59.129  NaN  NaN  NaN
# 2002 [YR2002]  72.061      76.936585    71.089      59.717  NaN  NaN  NaN
# 2003 [YR2003]  72.381      77.036585    71.389      60.256  NaN  NaN  NaN
# 2004 [YR2004]  72.689      77.487805    71.728      60.752  NaN  NaN  NaN
# 2005 [YR2005]  72.985      77.487805    72.099      61.212  NaN  NaN  NaN
# 2009 [YR2009]  74.119      78.390244    73.766      62.944  NaN  NaN  NaN
# 2010 [YR2010]  74.409      78.541463    74.184      63.388  NaN  NaN  NaN
# 2011 [YR2011]  74.708      78.641463    74.593      63.836  NaN  NaN  NaN
# 2012 [YR2012]  75.013      78.741463    74.992      64.280  NaN  NaN  NaN
# 2013 [YR2013]  75.321      78.741463    75.378      64.713  NaN  NaN  NaN
# 2014 [YR2014]  75.629      78.841463    75.747      65.133  NaN  NaN  NaN
# 2015 [YR2015]  75.928      78.690244    76.091      65.539  NaN  NaN  NaN
# ...

# %%
csv1_df['China']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'China'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %%
csv1_df.China.plot(legend=True) #plot usa column
plt.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Input In [111], in <cell line: 1>()
# ----> 1 csv1_df.China.plot(legend=True) #plot usa column
#       2 plt.show()
#
# File ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py:5575, in NDFrame.__getattr__(self, name)
#    5568 if (
#    5569     name not in self._internal_names_set
#    5570     and name not in self._metadata
#    5571     and name not in self._accessors
#    5572     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5573 ):
#    5574     return self[name]
# -> 5575 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'China'

# %%
csv1_df.shape
# Out:
# (8, 7)

# %%
csv2_df = pd.read_csv(
    'e8fd8d18-5a49-4f9f-a1c2-e74f1427deec_Data.csv'
)

csv2_df.head()
# Out:
#     Country Name Country Code        Series Name     Series Code  \
# 0          China          CHN  GDP (current US$)  NY.GDP.MKTP.CD
# 1  United States          USA  GDP (current US$)  NY.GDP.MKTP.CD
# 2       Thailand          THA  GDP (current US$)  NY.GDP.MKTP.CD
# 3     Madagascar          MDG  GDP (current US$)  NY.GDP.MKTP.CD
# 4            NaN          NaN                NaN             NaN
#
#    2001 [YR2001]  2002 [YR2002]  2003 [YR2003]  2004 [YR2004]  2005 [YR2005]  \
# 0   1.339396e+12   1.470550e+12   1.660288e+12   1.955347e+12   2.285966e+12
# 1   1.058193e+13   1.092911e+13   1.145644e+13   1.221719e+13   1.303920e+13
# 2   1.202965e+11   1.343009e+11   1.522807e+11   1.728957e+11   1.893185e+11
# 3   5.438333e+09   5.351702e+09   6.372499e+09   5.064733e+09   5.859270e+09
# 4            NaN            NaN            NaN            NaN            NaN
#
#    2009 [YR2009]  2010 [YR2010]  2011 [YR2011]  2012 [YR2012]  2013 [YR2013]  \
# ...
